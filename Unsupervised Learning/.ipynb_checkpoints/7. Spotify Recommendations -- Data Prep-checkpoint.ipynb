# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import re
import numpy as np
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='cf5e39da3b50438493846ee960df886d',client_secret='23e7cc1dcb4f4836bc594667c6e2cef3')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def track_features(trackId):
    features = sp.audio_features(trackId)[0]
    artist = sp.track(trackId)['artists'][0]['id']
    artist_pop = sp.artist(artist)['popularity']
    artist_genres =  sp.artist(artist)['genres']
    
    track_pop = sp.track(trackId)['popularity']
    
    features['artist_pop'] = artist_pop
    if artist_genres:
        features['genres'] = " ".join([re.sub(' ','_',i) for i in artist_genres])
    else:
        features['genres'] = 'unknown'
        
    features['track_pop'] = track_pop
    
    return features

# %%
playlist = sp.playlist('37i9dQZF1DWXRqgorJj26U')

playlist_df = pd.DataFrame(columns=['artist_name','track_uri','artist_uri','track_name','album_uri','duration_ms','album_name'])

for i in range(0,len(playlist['tracks']['items'])):
    attribute_list=[]
    attribute_list.append(playlist['tracks']['items'][i]['track']['artists'][0]['name'])
    attribute_list.append(playlist['tracks']['items'][i]['track']['uri'])
    attribute_list.append(playlist['tracks']['items'][i]['track']['artists'][0]['uri'])
    attribute_list.append(playlist['tracks']['items'][i]['track']['name'])
    attribute_list.append(playlist['tracks']['items'][i]['track']['album']['uri'])
    attribute_list.append(playlist['tracks']['items'][i]['track']['duration_ms'])
    attribute_list.append(playlist['tracks']['items'][i]['track']['album']['name'])
    playlist_df.loc[len(playlist_df)] = attribute_list

playlist_df['track_uri'] = playlist_df['track_uri'].apply(lambda x:x[x.rfind(':')+1:])

playlist_df.head()
# Out:
#      artist_name               track_uri  \
# 0  Fleetwood Mac  0ofHAoxe9vBkTCp2UQIavz
# 1  Guns N' Roses  3YBZIN3rekqsKxbJc9FZko
# 2          Queen  57JVGBtBLCfHw2muk5416J
# 3          AC/DC  2zYzyRzz6pRmhPzyfMEC8s
# 4      The Clash  39shmbIHICJ2Wxnk1fPSdz
#
#                               artist_uri  \
# 0  spotify:artist:08GQAI4eElDnROBrJRGE0X
# 1  spotify:artist:3qm84nBOXUEQ2vnTfUTTFC
# 2  spotify:artist:1dfeR4HaWDbWqFHLkxsg1d
# 3  spotify:artist:711MCceyCBcFnzjGY4Q7Un
# 4  spotify:artist:3RGLhK1IP9jnYFH4BRFJBS
#
#                                      track_name  \
# 0                        Dreams - 2004 Remaster
# 1                                 Paradise City
# 2  Another One Bites The Dust - Remastered 2011
# 3                               Highway to Hell
# 4     Should I Stay or Should I Go - Remastered
#
#                               album_uri  duration_ms  \
# 0  spotify:album:0BwWUstDMUbgq2NYONRqlu       257800
# 1  spotify:album:3I9Z1nDCL4E0cP62flcbI5       405640
# 2  spotify:album:6wPXUmYJ9mOWrKlLzZ5cCa       214653
# 3  spotify:album:10v912xgTZbjAtYfyKWJCS       208400
# 4  spotify:album:1ZH5g1RDq3GY1OvyD0w0s2       188986
#
#                              album_name
# 0                Rumours (Super Deluxe)
# 1              Appetite For Destruction
# 2  The Game (Deluxe Remastered Version)
# 3                       Highway to Hell
# 4              Combat Rock (Remastered)

# %%
key_columns=[]
for key in track_features(playlist_df['track_uri'][0]):
    key_columns.append(key)

track_features_df = pd.DataFrame(columns=key_columns)

featureList = []
for i in range(0,len(playlist_df)):
#     print(i)
    featureList.append(track_features(playlist_df['track_uri'][i]))

track_features_df = pd.DataFrame(featureList)

track_features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.828   0.492    0    -9.744     1       0.0276        0.0644
# 1         0.273   0.952   11    -8.762     1       0.0843        0.0169
# 2         0.933   0.528    5    -6.472     0       0.1620        0.1120
# 3         0.574   0.913    6    -4.793     0       0.1330        0.0610
# 4         0.743   0.836    2    -6.465     1       0.1160        0.0804
#
#    instrumentalness  liveness  valence  ...            type  \
# 0           0.00428     0.128    0.789  ...  audio_features
# 1           0.01110     0.142    0.472  ...  audio_features
# 2           0.32900     0.163    0.756  ...  audio_features
# 3           0.00158     0.156    0.423  ...  audio_features
# 4           0.00000     0.384    0.820  ...  audio_features
#
#                        id                                   uri  \
# 0  0ofHAoxe9vBkTCp2UQIavz  spotify:track:0ofHAoxe9vBkTCp2UQIavz
# 1  3YBZIN3rekqsKxbJc9FZko  spotify:track:3YBZIN3rekqsKxbJc9FZko
# 2  57JVGBtBLCfHw2muk5416J  spotify:track:57JVGBtBLCfHw2muk5416J
# 3  2zYzyRzz6pRmhPzyfMEC8s  spotify:track:2zYzyRzz6pRmhPzyfMEC8s
# 4  39shmbIHICJ2Wxnk1fPSdz  spotify:track:39shmbIHICJ2Wxnk1fPSdz
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0ofHAoxe9vBk...
# 1  https://api.spotify.com/v1/tracks/3YBZIN3rekqs...
# 2  https://api.spotify.com/v1/tracks/57JVGBtBLCfH...
# 3  https://api.spotify.com/v1/tracks/2zYzyRzz6pRm...
# 4  https://api.spotify.com/v1/tracks/39shmbIHICJ2...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0ofH...      257800
# 1  https://api.spotify.com/v1/audio-analysis/3YBZ...      405640
# 2  https://api.spotify.com/v1/audio-analysis/57JV...      214653
# 3  https://api.spotify.com/v1/audio-analysis/2zYz...      208400
# 4  https://api.spotify.com/v1/audio-analysis/39sh...      188987
#
#    time_signature  artist_pop  \
# 0               4          83
# 1               4          82
# 2               4          88
# 3               4          85
# 4               4          73
#
#                                               genres track_pop
# 0  album_rock classic_rock mellow_gold rock soft_...        86
# 1                          glam_metal hard_rock rock        80
# 2                        classic_rock glam_rock rock        75
# 3                     australian_rock hard_rock rock        85
# 4              classic_rock permanent_wave punk rock        81
#
# [5 rows x 21 columns]

# %%
music_df = pd.merge(playlist_df,track_features_df,left_on='track_uri',right_on = 'id')

# %%
music_df = music_df.drop_duplicates()

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_name       100 non-null    object
#  1   track_uri         100 non-null    object
#  2   artist_uri        100 non-null    object
#  3   track_name        100 non-null    object
#  4   album_uri         100 non-null    object
#  5   duration_ms_x     100 non-null    int64
#  6   album_name        100 non-null    object
#  7   danceability      100 non-null    float64
#  8   energy            100 non-null    float64
#  9   key               100 non-null    int64
#  10  loudness          100 non-null    float64
#  11  mode              100 non-null    int64
#  12  speechiness       100 non-null    float64
#  13  acousticness      100 non-null    float64
#  14  instrumentalness  100 non-null    float64
#  15  liveness          100 non-null    float64
#  16  valence           100 non-null    float64
#  17  tempo             100 non-null    float64
#  18  type              100 non-null    object
#  19  id                100 non-null    object
#  20  uri               100 non-null    object
#  21  track_href        100 non-null    object
#  22  analysis_url      100 non-null    object
#  23  duration_ms_y     100 non-null    int64
#  24  time_signature    100 non-null    int64
#  25  artist_pop        100 non-null    int64
#  26  genres            100 non-null    object
#  27  track_pop         100 non-null    int64
# dtypes: float64(9), int64(7), object(12)
# memory usage: 22.7+ KB

# %%
music_df.describe()
# Out:
#        duration_ms_x  danceability      energy         key    loudness  \
# count     100.000000     100.00000  100.000000  100.000000  100.000000
# mean   259648.400000       0.53756    0.735280    4.880000   -7.785400
# std     76927.732823       0.14892    0.181449    3.576805    3.005675
# min    121160.000000       0.25600    0.322000    0.000000  -17.180000
# 25%    214166.250000       0.42900    0.600250    2.000000   -9.929750
# 50%    253735.000000       0.53750    0.797000    4.000000   -7.468000
# 75%    293506.500000       0.64250    0.884000    8.250000   -5.533000
# max    536066.000000       0.93300    0.989000   11.000000   -3.205000
#
#              mode  speechiness  acousticness  instrumentalness    liveness  \
# count  100.000000   100.000000    100.000000        100.000000  100.000000
# mean     0.740000     0.063472      0.122604          0.044562    0.187723
# std      0.440844     0.059780      0.168213          0.113675    0.127285
# min      0.000000     0.025300      0.000025          0.000000    0.032700
# 25%      0.000000     0.033875      0.007075          0.000009    0.085675
# 50%      1.000000     0.043900      0.053000          0.000320    0.141000
# 75%      1.000000     0.062700      0.185500          0.011250    0.283250
# max      1.000000     0.405000      0.686000          0.581000    0.659000
#
#           valence       tempo  duration_ms_y  time_signature  artist_pop  \
# count  100.000000  100.000000     100.000000          100.00  100.000000
# mean     0.618120  121.140130  259648.710000            3.99   76.320000
# std      0.231081   27.695616   76927.698691            0.10    6.878278
# min      0.104000   71.105000  121160.000000            3.00   54.000000
# 25%      0.468500  102.905000  214166.500000            4.00   71.000000
# 50%      0.644500  118.775000  253736.000000            4.00   76.000000
# 75%      0.793500  134.053250  293506.750000            4.00   82.000000
# max      0.965000  203.006000  536067.000000            4.00   89.000000
#
#         track_pop
# count  100.000000
# mean    62.970000
# std     29.045229
# min      0.000000
# 25%     65.000000
# 50%     76.000000
# 75%     80.000000
# max     86.000000

# %%
music_df.to_csv('C:\\Users\\Akhil_S_Bhat\\Documents\\AIML\Machine_Learning\\Unsupervised Learning\\Data\\3_Spotify_Data\\spotify_test_data.csv')
